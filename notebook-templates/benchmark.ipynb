# %% [markdown]
# ---
# title: {{title}}
# category: {{category}}
# tags:
# {{tags}}
# date: {{date}}
# status: draft
# description: {{description}}
# sources:
# {{sources}}
# notebook_page: {{notebook_page}}
# ---
#
# ## Question
#
# State the performance or quality question and the decision the result informs.

# %%
import os
import platform
import random
import sys
import time
import warnings

import numpy as np

warnings.filterwarnings("ignore")
os.environ.setdefault("TOKENIZERS_PARALLELISM", "false")
SEED = 7
random.seed(SEED)
np.random.seed(SEED)
print({"python": sys.version.split()[0], "platform": platform.platform()})

# %% [markdown]
# ## Setup and Workload
#
# Record hardware, software versions, flags, input shapes, data provenance, controls, and the baseline. Define each reported unit.

# %%
# Prepare the workload outside the timed region.

# %% [markdown]
# ## Method
#
# Set warmup, repetition count, synchronization, randomization, and aggregation before collecting results.

# %%
WARMUP = 5
REPETITIONS = 30

# Run warmups, collect raw observations, and retain them for inspection.

# %% [markdown]
# ## Results and Interpretation
#
# Report the raw or compact result table with units and variability. Separate the observation from the mechanism you infer.
#
# ## Reproduction
#
# Record runtime, exact dependencies, data location, and the command used to execute this notebook.

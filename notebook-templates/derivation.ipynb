# %% [markdown]
# ---
# title: {{title}}
# category: {{category}}
# tags:
# {{tags}}
# date: {{date}}
# status: draft
# description: {{description}}
# sources:
# {{sources}}
# notebook_page: {{notebook_page}}
# ---
#
# ## Goal
#
# State the identity, gradient, estimator, or algorithm to derive and verify.

# %%
import os
import warnings

import numpy as np

warnings.filterwarnings("ignore")
os.environ.setdefault("TOKENIZERS_PARALLELISM", "false")
np.random.seed(7)

# %% [markdown]
# ## Assumptions and Notation
#
# Define every symbol, tensor shape, regularity condition, and convention used below.
#
# ## Derivation
#
# Show the nontrivial intermediate steps and cite the underlying theorem or primary source.

# %%
# Implement the derived expression directly with NumPy.

# %% [markdown]
# ## Numerical Verification
#
# Compare against finite differences, autodiff, a trusted implementation, or a known invariant. State tolerances before testing.

# %%
# Run numerical checks over representative and edge-case inputs.

# %% [markdown]
# ## Limits and Reproduction
#
# Record where the derivation fails, numerical stability concerns, dependency versions, and the execution command.

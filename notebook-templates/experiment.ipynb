# %% [markdown]
# ---
# title: {{title}}
# category: {{category}}
# tags:
# {{tags}}
# date: {{date}}
# status: draft
# description: {{description}}
# sources:
# {{sources}}
# notebook_page: {{notebook_page}}
# ---
#
# ## Question
#
# State the question, expected result, and the decision this experiment informs.

# %%
import os
import random
import warnings

import numpy as np

warnings.filterwarnings("ignore")
os.environ.setdefault("HF_HUB_DISABLE_PROGRESS_BARS", "1")
os.environ.setdefault("HF_HUB_VERBOSITY", "error")
os.environ.setdefault("DATASETS_VERBOSITY", "error")
os.environ.setdefault("TOKENIZERS_PARALLELISM", "false")
SEED = 7
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Data and Provenance
#
# Link the dataset card or primary source. Record the split, filters, preprocessing, license, and downloaded-data location.

# %%
# Load a small public dataset or construct clearly labeled synthetic data.
# Keep downloads under work/notebook-data/.

# %% [markdown]
# ## Method
#
# Define the model, baseline, metric, controls, and assumptions before running the experiment. Include the relevant math.

# %%
# Run the experiment and retain the compact outputs used by the note.

# %% [markdown]
# ## Interpretation
#
# Describe the observed result, uncertainty, failure cases, and what the measurement supports.
#
# ## Environment and Reproduction
#
# Record hardware, Python and library versions, runtime, and the command used to execute this notebook.
